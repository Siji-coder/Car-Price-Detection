# %%
import pandas as pd
data=pd.read_excel("CarPrice_EDA_WorkBook.xlsx")

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   car_ID       205 non-null    int64
#  1   CarName      205 non-null    object
#  2   carbody      205 non-null    object
#  3   wheelbase    205 non-null    float64
#  4   carlength    205 non-null    float64
#  5   carwidth     205 non-null    float64
#  6   carheight    205 non-null    float64
#  7   Carweight    205 non-null    int64
#  8   enginesize   205 non-null    int64
#  9   horsepower   205 non-null    int64
#  10  peakrpm      205 non-null    int64
#  11  citympg      205 non-null    int64
#  12  highwaympg   205 non-null    int64
#  13  price        205 non-null    float64
#  14  Unnamed: 14  0 non-null      float64
#  15  Unnamed: 15  2 non-null      float64
#  16  Unnamed: 16  2 non-null      float64
# dtypes: float64(8), int64(7), object(2)
# memory usage: 27.4+ KB

# %%
data.isnull()
# Out:
#      car_ID  CarName  carbody  wheelbase  carlength  carwidth  carheight  \
# 0     False    False    False      False      False     False      False
# 1     False    False    False      False      False     False      False
# 2     False    False    False      False      False     False      False
# 3     False    False    False      False      False     False      False
# 4     False    False    False      False      False     False      False
# ..      ...      ...      ...        ...        ...       ...        ...
# 200   False    False    False      False      False     False      False
# 201   False    False    False      False      False     False      False
# 202   False    False    False      False      False     False      False
# 203   False    False    False      False      False     False      False
# 204   False    False    False      False      False     False      False
#
#      Carweight  enginesize  horsepower  peakrpm  citympg  highwaympg  price  \
# ...

# %%
data.drop('Unnamed: 14',axis=1)
# Out:
#      car_ID                   CarName      carbody  wheelbase  carlength  \
# 0         1        alfa-romero giulia  convertible       88.6      168.8
# 1         2       alfa-romero stelvio  convertible       88.6      168.8
# 2         3  alfa-romero Quadrifoglio    hatchback       94.5      171.2
# 3         4               audi 100 ls        sedan       99.8      176.6
# 4         5                audi 100ls        sedan       99.4      176.6
# ..      ...                       ...          ...        ...        ...
# 200     201           volvo 145e (sw)        sedan      109.1      188.8
# 201     202               volvo 144ea        sedan      109.1      188.8
# 202     203               volvo 244dl        sedan      109.1      188.8
# 203     204                 volvo 246        sedan      109.1      188.8
# 204     205               volvo 264gl        sedan      109.1      188.8
#
#      carwidth  carheight  Carweight  enginesize  horsepower  peakrpm  citympg  \
# ...

# %%
df=data.drop(['Unnamed: 14','Unnamed: 15','Unnamed: 16'],axis=1)

# %%
df.isna().sum()
# Out:
# car_ID        0
# CarName       0
# carbody       0
# wheelbase     0
# carlength     0
# carwidth      0
# carheight     0
# Carweight     0
# enginesize    0
# horsepower    0
# peakrpm       0
# citympg       0
# highwaympg    0
# price         0
# dtype: int64

# %%
df.dtypes
# Out:
# car_ID          int64
# CarName        object
# carbody        object
# wheelbase     float64
# carlength     float64
# carwidth      float64
# carheight     float64
# Carweight       int64
# enginesize      int64
# horsepower      int64
# peakrpm         int64
# citympg         int64
# highwaympg      int64
# price         float64
# dtype: object

# %%
df.isna().mean()*100
# Out:
# car_ID        0.0
# CarName       0.0
# carbody       0.0
# wheelbase     0.0
# carlength     0.0
# carwidth      0.0
# carheight     0.0
# Carweight     0.0
# enginesize    0.0
# horsepower    0.0
# peakrpm       0.0
# citympg       0.0
# highwaympg    0.0
# price         0.0
# dtype: float64

# %%
df.describe()
# Out:
#            car_ID   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000   98.756585  174.049268   65.907805   53.724878
# std     59.322565    6.021776   12.337289    2.145204    2.443522
# min      1.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000  120.900000  208.100000   72.300000   59.800000
#
#          Carweight  enginesize  horsepower      peakrpm     citympg  \
# count   205.000000  205.000000  205.000000   205.000000  205.000000
# mean   2555.565854  126.907317  104.117073  5125.121951   25.219512
# std     520.680204   41.642693   39.544167   476.985643    6.542142
# min    1488.000000   61.000000   48.000000  4150.000000   13.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(df['car_ID'])
# Out:
# <AxesSubplot:xlabel='car_ID'>

# %%
sns.boxplot(df['wheelbase'])
# Out:
# <AxesSubplot:xlabel='wheelbase'>

# %%
sns.boxplot(df['carlength'])
# Out:
# <AxesSubplot:xlabel='carlength'>

# %%
sns.boxplot(df['carwidth'])
# Out:
# <AxesSubplot:xlabel='carwidth'>

# %%
sns.boxplot(df['carheight'])
# Out:
# <AxesSubplot:xlabel='carheight'>

# %%
df.skew()
# Out:
# car_ID        0.000000
# wheelbase     1.050214
# carlength     0.155954
# carwidth      0.904003
# carheight     0.063123
# Carweight     0.681398
# enginesize    1.947655
# horsepower    1.405310
# peakrpm       0.075159
# citympg       0.663704
# highwaympg    0.539997
# price         1.777678
# dtype: float64

# %%
sns.pairplot(df)

# %%
df['CarName']
# Out:
# 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero Quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
#                  ...
# 200             volvo 145e (sw)
# 201                 volvo 144ea
# 202                 volvo 244dl
# 203                   volvo 246
# 204                 volvo 264gl
# Name: CarName, Length: 205, dtype: object
